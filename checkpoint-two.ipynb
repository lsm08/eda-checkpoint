# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset: [<span style="color:#1155CC">https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023</span>](https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023)
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
df = pd.read_csv('./ds_salaries.csv') 
df.head()# displays the first 5 rows of a dataframe
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
# df.describe # to get stastics for the numerical columns
print(df.describe)
# shows the summary of the data
print(df.info)  

# displays all column names
print(df.columns) 

missing_values = df.isnull().sum() # finding missing values in data
print(missing_values) 

df.nunique() # displays unique values in each column of the data

duplicate_rows = df[df.duplicated(keep='first')]
num_duplicates = duplicate_rows.shape[0]
print(num_duplicates)
# Out:
# <bound method NDFrame.describe of       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
average_salary = df[['job_title','salary_in_usd']].groupby('job_title').mean().sort_values(by='salary_in_usd',ascending = False)
print(average_salary)
top5_high_salaries = average_salary.head(5)
print(top5_high_salaries)
# Out:
#                                salary_in_usd
# job_title
# Data Science Tech Lead            375000.000
# Cloud Data Architect              250000.000
# Data Lead                         212500.000
# Data Analytics Lead               211254.500
# Principal Data Scientist          198171.125
# ...                                      ...
# Autonomous Vehicle Technician      26277.500
# 3D Computer Vision Researcher      21352.250
# Staff Data Analyst                 15000.000
# Product Data Scientist              8000.000
# Power BI Developer                  5409.000
#
# [93 rows x 1 columns]
#                           salary_in_usd
# job_title
# Data Science Tech Lead       375000.000
# Cloud Data Architect         250000.000
# Data Lead                    212500.000
# Data Analytics Lead          211254.500
# Principal Data Scientist     198171.125

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
# Creating a plot to show top 5 jobs by salary
plt.figure(figsize=(20, 6))
print(top5_high_salaries)
plt.bar(top5_high_salaries.index, top5_high_salaries ['salary_in_usd'])
plt.xlabel('Job Title')
plt.ylabel('Salary (USD)')
plt.title('Top 5 Highest Paid Data Science Jobs')
plt.show()
# Out:
#                           salary_in_usd
# job_title
# Data Science Tech Lead       375000.000
# Cloud Data Architect         250000.000
# Data Lead                    212500.000
# Data Analytics Lead          211254.500
# Principal Data Scientist     198171.125

# %%
#Visualize salaries by company location
# print('columns', df.columns)
salary_by_location = df[['company_location','salary_in_usd']].groupby('company_location').mean().sort_values(by='salary_in_usd', ascending = False)
plt.figure(figsize=(20, 5))

plt.bar(salary_by_location.index, salary_by_location['salary_in_usd'], )
plt.title('Average Salary by Location')
plt.xlabel('Company Location')
plt.ylabel('Average Salary')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# 1. Data size was small with only one file /dataframe
# 3. Do you have any concerns about your dataset?
# 1. Duplicates, different salaries for the same title and location
# 5. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# 1. Identify key attributes and clean up duplicate rows.

# %% [markdown]
# Answers:
#
# 1. Data size was small with only one file /dataframe
# 2. <span style="color: var(--vscode-foreground);">data is not very clean - different salaries for the same title and location. No data for company size column.</span>
# 3. <span style="color: var(--vscode-foreground);">Identify key attributes and clean up duplicate rows.</span>
